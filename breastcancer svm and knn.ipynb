# %%
import pandas as pd

# %%
df=pd.read_csv("breast_cancer_data.csv")

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
(df["target"].value_counts()/len(df))*100
# Out:
# target
# 1    62.741652
# 0    37.258348
# Name: count, dtype: float64

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# %%
##  divide the the data into train and test
x=df.drop(columns=["target"])

# %%
y=df["target"]

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
## random state genrate reproduceability

# %%
## scale the feature
scaler=StandardScaler()

# %%
x_train_scaler=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
## train the sum model
svm_model=SVC(kernel="rbf",C=1,gamma="scale")
svm_model.fit(x_train_scaler,y_train)
# Out:
# SVC(C=1)

# %%
## predict and evalute
y_pred=svm_model.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score
acc_svm=accuracy_score(y_test,y_pred)
print("accuracy score:",acc)
# Out:
# accuracy score: 0.972027972027972

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train_scaler,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_pred=knn.predict(x_test_scaled)

# %%
acc_svm=accuracy_score(y_test,knn_pred)

# %%
print("accuracy score:",acc_svm)
# Out:
# accuracy score: 0.958041958041958

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

# %% [markdown]
# ## svm with cross validation

# %%
x_scaler=scaler.fit_transform(x)

# %%
svm_score=cross_val_score(svm_model,x_scaler,y,cv=5,scoring="accuracy")

# %%
svm_score
# Out:
# array([0.97368421, 0.95614035, 1.        , 0.96491228, 0.97345133])

# %%
print("svm average accuracy is",np.mean(svm_score))
# Out:
# svm average accuracy is 0.9736376339077782

# %% [markdown]
# ## KNN with cross validation

# %%
knn_score=cross_val_score(knn,x_scaler,y,cv=5,scoring="accuracy")

# %%
print("knnaverage accuracy is",np.mean(knn_score))
# Out:
# knnaverage accuracy is 0.9648501785437045

# %%
from sklearn.model_selection import StratifiedKFold
